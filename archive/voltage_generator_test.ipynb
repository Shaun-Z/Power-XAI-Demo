# %%
from voltage_generator import DistributionNetwork
import argparse

# %%
parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter, description='Distribution Network Simulator')

# %%
parser = DistributionNetwork.get_args(parser)
args, _ = parser.parse_known_args(args=[])
args.file_path='./structure/Node123_loop.txt'
args

# %%
dnet = DistributionNetwork(args)

# %%
import numpy as np

# %%
dnet.Y_reduced_outage.shape

# %%
np.linalg.inv(dnet.Y_reduced_outage)

# %%
dnet.print_info()

# %%
dnet.plot()

# %%
dnet.draw_network()

# %%
dnet.save_data()
