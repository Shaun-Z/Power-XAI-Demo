# %% [markdown]
# # Scripts for Training

# %% [markdown]
# ## CNN

# %%
# !python train.py --model cnn --batch_size 512 --epochs 500 --lr 0.001 --dataset Node8_loop
# Out:
# Using device: cuda
# Model architecture: CnnClassifier(
#   (features): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(2,), stride=(1,), padding=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(32, 64, kernel_size=(2,), stride=(1,), padding=(1,))
#     (3): ReLU(inplace=True)
#     (4): Conv1d(64, 128, kernel_size=(2,), stride=(1,), padding=(1,))
#     (5): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): LazyLinear(in_features=0, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
# Starting training for 500 epochs...
# Epoch 1/500, Train Loss: 0.6969, Test Loss: 0.6916
# Model saved to checkpoints/Node8_loop/cnn_model.pth
# Epoch 2/500, Train Loss: 0.6898, Test Loss: 0.6832
# Model saved to checkpoints/Node8_loop/cnn_model.pth
# Epoch 3/500, Train Loss: 0.6789, Test Loss: 0.6692
# ...

# %% [markdown]
# ## MLP

# %%
# !python train.py --model mlp --batch_size 512 --epochs 500 --lr 0.005 --dataset Node8_loop
# Out:
# Using device: cuda
# Model architecture: MLPClassifier(
#   (fc1): Linear(in_features=7, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=1, bias=True)
# )
# Starting training for 500 epochs...
# Epoch 1/500, Train Loss: 0.6816, Test Loss: 0.6630
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# Epoch 2/500, Train Loss: 0.6553, Test Loss: 0.6295
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# Epoch 3/500, Train Loss: 0.6241, Test Loss: 0.6025
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# Epoch 4/500, Train Loss: 0.5984, Test Loss: 0.5754
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# Epoch 5/500, Train Loss: 0.5733, Test Loss: 0.5487
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# Epoch 6/500, Train Loss: 0.5470, Test Loss: 0.5201
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# Epoch 7/500, Train Loss: 0.5156, Test Loss: 0.4921
# Model saved to checkpoints/Node8_loop/mlp_model.pth
# ...

# %% [markdown]
# ## Transformer

# %%
# !python train.py --model transformer --batch_size 512 --epochs 500 --lr 0.005 --dataset Node8_loop
# Out:
# Using device: cuda
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Model architecture: TransformerClassifier(
#   (embedding): Linear(in_features=1, out_features=64, bias=True)
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (linear1): Linear(in_features=64, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=128, out_features=64, bias=True)
# ...

# %% [markdown]
# ## LSTM

# %%
# !python train.py --model lstm --batch_size 512 --epochs 500 --lr 0.005 --dataset Node8_loop
# Out:
# Using device: cuda
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Model architecture: LSTMClassifier(
#   (lstm): LSTM(1, 128, batch_first=True, dropout=0.1)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )
# Starting training for 500 epochs...
# Epoch 1/500, Train Loss: 0.6895, Test Loss: 0.6790
# Model saved to checkpoints/Node8_loop/lstm_model.pth
# Epoch 2/500, Train Loss: 0.6582, Test Loss: 0.6473
# Model saved to checkpoints/Node8_loop/lstm_model.pth
# Epoch 3/500, Train Loss: 0.6310, Test Loss: 0.6608
# Model saved to checkpoints/Node8_loop/lstm_model.pth
# Epoch 4/500, Train Loss: 0.6155, Test Loss: 0.6179
# Model saved to checkpoints/Node8_loop/lstm_model.pth
# Epoch 5/500, Train Loss: 0.6246, Test Loss: 0.5601
# ...

# %% [markdown]
# # Scripts for Explaining

# %% [markdown]
# ## Owen

# %% [markdown]
# ### CNN

# %%
# !python explain_owen.py --model cnn --dataset Node8_loop --output_dir owen_results
# Out:
# Results will be saved to: owen_results/cnn_Node8_loop
# Loaded Node8_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/cnn_model.pth
# Label 0 samples shape: (800, 1, 7)
# Label 1 samples shape: (800, 1, 7)
# Background shape: (2, 7)
# Model prediction for sample instance: 1.0
# 2025-03-26 20:10:41.245815: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-26 20:10:41.252332: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ### MLP

# %%
# !python explain_owen.py --model mlp --dataset Node8_loop --output_dir owen_results
# Out:
# Results will be saved to: owen_results/mlp_Node8_loop
# Loaded Node8_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/mlp_model.pth
# Label 0 samples shape: (800, 1, 7)
# Label 1 samples shape: (800, 1, 7)
# Background shape: (2, 7)
# Model prediction for sample instance: 1.0
# 2025-03-26 20:13:10.240123: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-26 20:13:10.246662: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ### Transformer

# %%
# !python explain_owen.py --model transformer --dataset Node8_loop --output_dir owen_results
# Out:
# Results will be saved to: owen_results/transformer_Node8_loop
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Loaded Node8_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/transformer_model.pth
# Label 0 samples shape: (800, 1, 7)
# Label 1 samples shape: (800, 1, 7)
# Background shape: (2, 7)
# Model prediction for sample instance: 1.0
# 2025-03-26 20:14:18.345322: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %% [markdown]
# ### LSTM

# %%
# !python explain_owen.py --model lstm --dataset Node8_loop --output_dir owen_results
# Out:
# Results will be saved to: owen_results/lstm_Node8_loop
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Loaded Node8_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/lstm_model.pth
# Label 0 samples shape: (800, 1, 7)
# Label 1 samples shape: (800, 1, 7)
# Background shape: (2, 7)
# Model prediction for sample instance: 1.0
# 2025-03-26 20:14:29.424518: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### CNN (Noisy)

# %%
# !python explain_owen.py --model cnn --dataset Node123_loop_noisy --output_dir owen_results
# Out:
# Results will be saved to: owen_results/cnn_Node123_loop_noisy
# Loaded Node123_loop_noisy dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/cnn_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-03-26 03:17:46.691893: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-26 03:17:46.698573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ### MLP (Noisy)

# %%
# !python explain_owen.py --model mlp --dataset Node123_loop_noisy --output_dir owen_results
# Out:
# Results will be saved to: owen_results/mlp_Node123_loop_noisy
# Loaded Node123_loop_noisy dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/mlp_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-03-26 03:18:22.139458: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-26 03:18:22.146202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ### Transformer (Noisy)

# %%
# !python explain_owen.py --model transformer --dataset Node123_loop_noisy --output_dir owen_results
# Out:
# Results will be saved to: owen_results/transformer_Node123_loop_noisy
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Loaded Node123_loop_noisy dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/transformer_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-03-26 03:18:53.919034: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %% [markdown]
# ### LSTM (Noisy)

# %%
# !python explain_owen.py --model lstm --dataset Node123_loop_noisy --output_dir owen_results
# Out:
# Results will be saved to: owen_results/lstm_Node123_loop_noisy
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Loaded Node123_loop_noisy dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/lstm_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-03-26 03:19:38.937949: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %% [markdown]
# ## SHAP

# %% [markdown]
# ### CNN

# %%
# !python explain_shap.py --model cnn --dataset Node123_loop --output_dir shap_results
# Out:
# Results will be saved to: shap_results/cnn_Node123_loop
# Loaded Node123_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/cnn_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-04-11 16:26:51.411696: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-11 16:26:51.418327: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ### MLP

# %%
# !python explain_shap.py --model mlp --dataset Node123_loop --output_dir shap_results
# Out:
# Results will be saved to: shap_results/mlp_Node123_loop
# Loaded Node123_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/mlp_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-04-11 16:27:32.312304: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-11 16:27:32.318958: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ### Transformer

# %%
# !python explain_shap.py --model transformer --dataset Node123_loop --output_dir shap_results
# Out:
# Results will be saved to: shap_results/transformer_Node123_loop
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Loaded Node123_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/transformer_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-04-11 16:27:38.875228: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %% [markdown]
# ### LSTM

# %%
# !python explain_shap.py --model lstm --dataset Node123_loop --output_dir shap_results
# Out:
# Results will be saved to: shap_results/lstm_Node123_loop
# /home/xiangyu/.conda/envs/PyTc/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Loaded Node123_loop dataset with 1600 training samples and 400 test samples
# Using model from checkpoints/lstm_model.pth
# Label 0 samples shape: (800, 1, 122)
# Label 1 samples shape: (800, 1, 122)
# Background shape: (2, 122)
# Model prediction for sample instance: 1.0
# 2025-04-11 16:27:52.687062: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
